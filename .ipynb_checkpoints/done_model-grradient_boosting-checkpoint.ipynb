# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
df= pd.read_excel("Combined All Stations_100m+PM25 added preci.xlsx")

# %%
df
# Out:
#          lat     lon        time  ALBDO_L1_Avg_1  DLWRF_L1_Avg_1  \
# 0     22.630  88.352  2021-01-01         5.98142      312.559000
# 1     22.630  88.352  2021-01-02         5.97004      313.683534
# 2     22.630  88.352  2021-01-03         5.93766      322.803813
# 3     22.630  88.352  2021-01-04         5.91420      333.227000
# 4     22.630  88.352  2021-01-05         5.89578      342.897000
# ...      ...     ...         ...             ...             ...
# 9725  22.545  88.340  2023-08-27        11.06430      447.360698
# 9726  22.545  88.340  2023-08-28        11.38305      446.798837
# 9727  22.545  88.340  2023-08-29        11.53260      449.412098
# 9728  22.545  88.340  2023-08-30        11.89660      444.362351
# 9729  22.545  88.340  2023-08-31        11.06580      449.656999
#
#       DSWRF_L1_Avg_1  FRICV_L1   GUST_L1     HPBL_L1  LAND_L1  ...  \
# 0         204.350000       NaN  3.826027  301.986018        1  ...
# 1         202.960000       NaN  3.101588  267.144669        1  ...
# 2         195.740000       NaN  2.774223  262.226417        1  ...
# 3         202.500000       NaN  2.184178  245.017254        1  ...
# 4         200.550000       NaN  2.317436  244.012100        1  ...
# ...              ...       ...       ...         ...      ...  ...
# 9725      218.351436  0.236240  4.011113  509.447365        1  ...
# 9726      254.572562  0.232510  3.222736  348.428543        1  ...
# 9727      170.017404  0.217375  2.810299  586.165287        1  ...
# 9728      238.533522  0.196937  2.842451  508.752148        1  ...
# 9729      214.339204  0.225425  3.711203  551.716328        1  ...
#
#       U_GRD_L103  ULWRF_L1_Avg_1  USWRF_L1_Avg_1  V_GRD_L103   VEG_L1  \
# 0       0.177358      421.298931        24.68100   -3.067933      NaN
# 1       0.641507      422.392632        24.65800   -2.350824      NaN
# 2      -0.116059      425.339199        23.57400   -2.127140      NaN
# 3      -0.406643      432.330161        24.27400   -1.479325      NaN
# 4      -0.299777      439.300757        24.09300   -0.909857      NaN
# ...          ...             ...             ...         ...      ...
# 9725    1.729183      480.649783        21.86660    1.165340  27.3940
# 9726    1.055720      491.225494        25.90458    0.574886  28.0470
# 9727    0.205340      486.897797        17.79536    0.228833  28.7160
# 9728    0.731016      494.799905        25.23142    0.528769  29.3645
# 9729    0.726602      497.759136        22.13280    1.884287  30.0405
#
#             VIS_L1  Station Name     PM 2.5       AOD  PRATE_L1_Avg_1
# 0     24135.001953    Belur Math  77.654583  0.581550    0.000000e+00
# 1     24135.046875    Belur Math  58.124737  0.425139    0.000000e+00
# 2     24135.080078    Belur Math        NaN  0.665841    0.000000e+00
# 3     24134.914062    Belur Math  76.667778  0.415729    0.000000e+00
# 4     24134.949219    Belur Math  92.684583  0.384968    0.000000e+00
# ...            ...           ...        ...       ...             ...
# 9725  24134.960938      Victoria  40.327917       NaN    3.322000e-06
# 9726  24134.876953      Victoria  60.819167       NaN    0.000000e+00
# 9727  24135.013672      Victoria  70.484583       NaN    1.620000e-07
# 9728  24134.886719      Victoria  68.857619       NaN    4.600000e-08
# 9729  24134.921875      Victoria  62.442083       NaN    5.260000e-07
#
# [9730 rows x 26 columns]

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
import pandas as pd

# Assuming your data is in a pandas DataFrame named 'df'
# Make sure your 'time' column is in datetime format
df['time'] = pd.to_datetime(df['time'])

# Filter data for dates between January 1, 2021, and December 31, 2022
date_range_start = '2021-01-01'
date_range_end = '2022-12-31'
date_mask = (df['time'] >= date_range_start) & (df['time'] <= date_range_end)
filtered_data = df[date_mask]

# Further filter based on 'PM 2.5' range
pm_mask = (filtered_data['PM 2.5'] >= 30) & (filtered_data['PM 2.5'] <= 250)
final_filtered_data = filtered_data[pm_mask]

# Create a new DataFrame with the filtered data
new_df = pd.DataFrame(final_filtered_data)

# Display the new DataFrame
print(new_df)
# Out:
#          lat     lon       time  ALBDO_L1_Avg_1  DLWRF_L1_Avg_1  \
# 0     22.630  88.352 2021-01-01         5.98142      312.559000
# 1     22.630  88.352 2021-01-02         5.97004      313.683534
# 3     22.630  88.352 2021-01-04         5.91420      333.227000
# 4     22.630  88.352 2021-01-05         5.89578      342.897000
# 5     22.630  88.352 2021-01-06         5.86226      355.172000
# ...      ...     ...        ...             ...             ...
# 9482  22.545  88.340 2022-12-27         5.61565      361.617300
# 9483  22.545  88.340 2022-12-28         5.65195      337.161187
# 9484  22.545  88.340 2022-12-29         5.74805      307.254359
# 9485  22.545  88.340 2022-12-30         5.71075      314.481768
# 9486  22.545  88.340 2022-12-31         5.71550      322.851497
#
#       DSWRF_L1_Avg_1  FRICV_L1   GUST_L1     HPBL_L1  LAND_L1  ...  \
# 0         204.350000       NaN  3.826027  301.986018        1  ...
# 1         202.960000       NaN  3.101588  267.144669        1  ...
# 3         202.500000       NaN  2.184178  245.017254        1  ...
# 4         200.550000       NaN  2.317436  244.012100        1  ...
# 5         198.774000       NaN  2.081998  263.980614        1  ...
# ...              ...       ...       ...         ...      ...  ...
# 9482      192.958251  0.239226  3.958173  403.533670        1  ...
# 9483      196.010448  0.293840  4.912187  394.828016        1  ...
# 9484      203.216849  0.245590  3.685035  370.541810        1  ...
# 9485      201.096702  0.158156  2.229730  352.894260        1  ...
# 9486      201.777245  0.156833  2.000811  293.269595        1  ...
#
#       U_GRD_L103  ULWRF_L1_Avg_1  USWRF_L1_Avg_1  V_GRD_L103     VEG_L1  \
# 0       0.177358      421.298931       24.681000   -3.067933        NaN
# 1       0.641507      422.392632       24.658000   -2.350824        NaN
# 3      -0.406643      432.330161       24.274000   -1.479325        NaN
# 4      -0.299777      439.300757       24.093000   -0.909857        NaN
# 5       1.169065      452.033445       23.774000   -0.265803        NaN
# ...          ...             ...             ...         ...        ...
# 9482    2.247126      448.608328       21.978480   -0.238416  18.688000
# 9483    0.292261      437.105191       22.483199   -3.372876  18.658500
# 9484    0.635704      421.643488       23.690880   -2.657268  18.578999
# 9485    0.984448      421.973019       23.313440   -1.411297  18.552000
# 9486    0.452528      432.576161       23.410040   -1.291892  18.479001
#
#             VIS_L1  Station Name      PM 2.5       AOD  PRATE_L1_Avg_1
# 0     24135.001953    Belur Math   77.654583  0.581550    0.000000e+00
# 1     24135.046875    Belur Math   58.124737  0.425139    0.000000e+00
# 3     24134.914062    Belur Math   76.667778  0.415729    0.000000e+00
# 4     24134.949219    Belur Math   92.684583  0.384968    0.000000e+00
# 5     24134.955078    Belur Math  132.424348  0.372209    0.000000e+00
# ...            ...           ...         ...       ...             ...
# 9482  23725.349258      Victoria   69.617500  0.843024    0.000000e+00
# 9483  24134.974609      Victoria  122.754583  0.701000    1.800000e-08
# 9484  24134.886719      Victoria  102.431667  0.626500    0.000000e+00
# 9485  24135.042969      Victoria  135.250833  0.746960    0.000000e+00
# 9486  24135.048828      Victoria  142.677500  0.810233    0.000000e+00
#
# [4160 rows x 26 columns]

# %%
new_df = new_df.drop(['FRICV_L1','LAND_L1','Station Name',"SFC_R_L1","VEG_L1","PRATE_L1_Avg_1","VIS_L1","USWRF_L1_Avg_1","DLWRF_L1_Avg_1","ULWRF_L1_Avg_1","U_GRD_L103"], axis=1)

# %%
# Remove rows with NaN values
new_df= new_df.dropna()

# %%
new_df
# Out:
#          lat     lon       time  ALBDO_L1_Avg_1  DSWRF_L1_Avg_1   GUST_L1  \
# 0     22.630  88.352 2021-01-01         5.98142      204.350000  3.826027
# 1     22.630  88.352 2021-01-02         5.97004      202.960000  3.101588
# 3     22.630  88.352 2021-01-04         5.91420      202.500000  2.184178
# 4     22.630  88.352 2021-01-05         5.89578      200.550000  2.317436
# 5     22.630  88.352 2021-01-06         5.86226      198.774000  2.081998
# ...      ...     ...        ...             ...             ...       ...
# 9482  22.545  88.340 2022-12-27         5.61565      192.958251  3.958173
# 9483  22.545  88.340 2022-12-28         5.65195      196.010448  4.912187
# 9484  22.545  88.340 2022-12-29         5.74805      203.216849  3.685035
# 9485  22.545  88.340 2022-12-30         5.71075      201.096702  2.229730
# 9486  22.545  88.340 2022-12-31         5.71550      201.777245  2.000811
#
#          HPBL_L1  LHTFL_L1_Avg_1        PRES_L1   R_H_L103  SHTFL_L1_Avg_1  \
# 0     301.986018       30.057888  101429.166812  39.441699       45.322859
# 1     267.144669       30.471104  101373.725500  31.246400       43.803595
# 3     245.017254       29.531700  101243.457063  41.387301       48.723233
# 4     244.012100       30.009221  101231.065125  41.939000       48.853329
# 5     263.980614       28.888099  101035.096312  39.217601       45.126278
# ...          ...             ...            ...        ...             ...
# 9482  403.533670       25.710091  101298.218750  54.042249       52.806470
# 9483  394.828016       29.517080  101423.074531  33.362249       54.177453
# 9484  370.541810       27.342413  101615.603281  28.919250       50.784719
# 9485  352.894260       25.946900  101644.569375  29.361000       52.307119
# 9486  293.269595       22.939286  101607.841719  36.544001       43.616447
#
#         TMP_L103  V_GRD_L103      PM 2.5       AOD
# 0     293.561722   -3.067933   77.654583  0.581550
# 1     293.357142   -2.350824   58.124737  0.425139
# 3     295.297473   -1.479325   76.667778  0.415729
# 4     296.791448   -0.909857   92.684583  0.384968
# 5     297.669039   -0.265803  132.424348  0.372209
# ...          ...         ...         ...       ...
# 9482  297.460245   -0.238416   69.617500  0.843024
# 9483  295.162292   -3.372876  122.754583  0.701000
# 9484  293.195768   -2.657268  102.431667  0.626500
# 9485  293.348338   -1.411297  135.250833  0.746960
# 9486  294.277830   -1.291892  142.677500  0.810233
#
# [4160 rows x 15 columns]

# %%
# high_pm= df[df['PM 2.5']>30]

# %%
# high_pm

# %%
# Assuming your DataFrame is named 'df'
X = new_df.drop(['PM 2.5',"time","lat","lon"], axis=1)  # Features (excluding the target variable)
y = new_df['PM 2.5']  # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
#print(X_test.dtypes)

# %%
# Create the model
rf_model = RandomForestRegressor(n_estimators=500, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=500, random_state=42)

# %%
from sklearn.model_selection import cross_val_score


# Assuming rf_model is your Random Forest model
cross_val_scores = cross_val_score(rf_model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
rmse_cross_val = np.sqrt(-cross_val_scores.mean())

print(f'Cross-Validated RMSE: {rmse_cross_val:.4f}')

# %%
feature_importance = pd.Series(rf_model.feature_importances_, index=X.columns)
feature_importance.sort_values(ascending=False, inplace=True)
print(feature_importance)

# %%
from sklearn.metrics import mean_squared_error, r2_score


# Make predictions on the training set
y_train_pred = rf_model.predict(X_train)

# Make predictions on the test set
y_test_pred = rf_model.predict(X_test)

# Calculate RMSE for training and testing sets
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Calculate R-squared for training and testing sets
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

# Display the results
print(f'Training RMSE: {rmse_train:.4f}')
print(f'Testing RMSE: {rmse_test:.4f}')

print(f'Training R-squared: {r2_train:.4f}')
print(f'Testing R-squared: {r2_test:.4f}')

# %%
import joblib

# Save the model to a file
model_filename = 'random_forest_model.pkl'
joblib.dump(rf_model, model_filename)

# %% [markdown]
# ready unseen data

# %%
df1= pd.read_excel("Combined All Stations_100m+PM25 added preci.xlsx")

# %%
# df['time'] = pd.to_datetime(df['time'])

# %%
import pandas as pd

# Assuming your data is in a pandas DataFrame named 'df'
# Make sure your 'time' column is in datetime format
df1['time'] = pd.to_datetime(df1['time'])

# Filter data for dates between January 1, 2021, and December 31, 2022
date_range_start = '2022-12-01'
date_range_end = '2022-12-31'
date_mask = (df1['time'] >= date_range_start) & (df1['time'] <= date_range_end)
filtered_data = df1[date_mask]

# Further filter based on 'PM 2.5' range
#pm_mask = (filtered_data['PM 2.5'] >= 30) & (filtered_data['PM 2.5'] <= 250)
final_filtered_data = filtered_data

# Create a new DataFrame with the filtered data
new_df1 = pd.DataFrame(final_filtered_data)

# Display the new DataFrame
print(new_df1)

# %%
new_df1= new_df1.dropna()

# %%
X_unseen = new_df1.drop(['PM 2.5','FRICV_L1','LAND_L1','Station Name',"time","lat","lon","VEG_L1","SFC_R_L1","PRATE_L1_Avg_1","VIS_L1","USWRF_L1_Avg_1","ULWRF_L1_Avg_1","U_GRD_L103"], axis=1)  # Features (excluding the target variable)

# %%
# Later, when you want to use the model for predictions on unseen data:
# Load the model from the file
import joblib
loaded_model = joblib.load(model_filename)

#Make predictions on unseen data (replace X_unseen with your actual unseen data)
y_unseen_pred = loaded_model.predict(X_unseen)

#Display the predictions on unseen data
print(y_unseen_pred)
pm=(new_df1["PM 2.5"])

# %%
rmse = np.sqrt(mean_squared_error(y_unseen_pred, pm))

# %%
rmse

# %%
r2_unseen = r2_score(y_unseen_pred, pm)

# %%
r2_unseen
