# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
df= pd.read_excel("Combined All Stations_100m+PM25 added preci.xlsx")

# %%
df
# Out:
#          lat     lon        time  ALBDO_L1_Avg_1  DLWRF_L1_Avg_1  \
# 0     22.630  88.352  2021-01-01         5.98142      312.559000
# 1     22.630  88.352  2021-01-02         5.97004      313.683534
# 2     22.630  88.352  2021-01-03         5.93766      322.803813
# 3     22.630  88.352  2021-01-04         5.91420      333.227000
# 4     22.630  88.352  2021-01-05         5.89578      342.897000
# ...      ...     ...         ...             ...             ...
# 9725  22.545  88.340  2023-08-27        11.06430      447.360698
# 9726  22.545  88.340  2023-08-28        11.38305      446.798837
# 9727  22.545  88.340  2023-08-29        11.53260      449.412098
# 9728  22.545  88.340  2023-08-30        11.89660      444.362351
# 9729  22.545  88.340  2023-08-31        11.06580      449.656999
#
#       DSWRF_L1_Avg_1  FRICV_L1   GUST_L1     HPBL_L1  LAND_L1  ...  \
# 0         204.350000       NaN  3.826027  301.986018        1  ...
# 1         202.960000       NaN  3.101588  267.144669        1  ...
# 2         195.740000       NaN  2.774223  262.226417        1  ...
# 3         202.500000       NaN  2.184178  245.017254        1  ...
# 4         200.550000       NaN  2.317436  244.012100        1  ...
# ...              ...       ...       ...         ...      ...  ...
# 9725      218.351436  0.236240  4.011113  509.447365        1  ...
# 9726      254.572562  0.232510  3.222736  348.428543        1  ...
# 9727      170.017404  0.217375  2.810299  586.165287        1  ...
# 9728      238.533522  0.196937  2.842451  508.752148        1  ...
# 9729      214.339204  0.225425  3.711203  551.716328        1  ...
#
#       U_GRD_L103  ULWRF_L1_Avg_1  USWRF_L1_Avg_1  V_GRD_L103   VEG_L1  \
# 0       0.177358      421.298931        24.68100   -3.067933      NaN
# 1       0.641507      422.392632        24.65800   -2.350824      NaN
# 2      -0.116059      425.339199        23.57400   -2.127140      NaN
# 3      -0.406643      432.330161        24.27400   -1.479325      NaN
# 4      -0.299777      439.300757        24.09300   -0.909857      NaN
# ...          ...             ...             ...         ...      ...
# 9725    1.729183      480.649783        21.86660    1.165340  27.3940
# 9726    1.055720      491.225494        25.90458    0.574886  28.0470
# 9727    0.205340      486.897797        17.79536    0.228833  28.7160
# 9728    0.731016      494.799905        25.23142    0.528769  29.3645
# 9729    0.726602      497.759136        22.13280    1.884287  30.0405
#
#             VIS_L1  Station Name     PM 2.5       AOD  PRATE_L1_Avg_1
# 0     24135.001953    Belur Math  77.654583  0.581550    0.000000e+00
# 1     24135.046875    Belur Math  58.124737  0.425139    0.000000e+00
# 2     24135.080078    Belur Math        NaN  0.665841    0.000000e+00
# 3     24134.914062    Belur Math  76.667778  0.415729    0.000000e+00
# 4     24134.949219    Belur Math  92.684583  0.384968    0.000000e+00
# ...            ...           ...        ...       ...             ...
# 9725  24134.960938      Victoria  40.327917       NaN    3.322000e-06
# 9726  24134.876953      Victoria  60.819167       NaN    0.000000e+00
# 9727  24135.013672      Victoria  70.484583       NaN    1.620000e-07
# 9728  24134.886719      Victoria  68.857619       NaN    4.600000e-08
# 9729  24134.921875      Victoria  62.442083       NaN    5.260000e-07
#
# [9730 rows x 26 columns]

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
import pandas as pd

# Assuming your data is in a pandas DataFrame named 'df'
# Make sure your 'time' column is in datetime format
df['time'] = pd.to_datetime(df['time'])

# Filter data for dates between January 1, 2021, and December 31, 2022
date_range_start = '2021-01-01'
date_range_end = '2022-12-31'
date_mask = (df['time'] >= date_range_start) & (df['time'] <= date_range_end)
filtered_data = df[date_mask]

# Further filter based on 'PM 2.5' range
pm_mask = (filtered_data['PM 2.5'] >= 30) & (filtered_data['PM 2.5'] <= 250)
final_filtered_data = filtered_data[pm_mask]

# Create a new DataFrame with the filtered data
new_df = pd.DataFrame(final_filtered_data)

# Display the new DataFrame
print(new_df)
# Out:
#          lat     lon       time  ALBDO_L1_Avg_1  DLWRF_L1_Avg_1  \
# 0     22.630  88.352 2021-01-01         5.98142      312.559000
# 1     22.630  88.352 2021-01-02         5.97004      313.683534
# 3     22.630  88.352 2021-01-04         5.91420      333.227000
# 4     22.630  88.352 2021-01-05         5.89578      342.897000
# 5     22.630  88.352 2021-01-06         5.86226      355.172000
# ...      ...     ...        ...             ...             ...
# 9482  22.545  88.340 2022-12-27         5.61565      361.617300
# 9483  22.545  88.340 2022-12-28         5.65195      337.161187
# 9484  22.545  88.340 2022-12-29         5.74805      307.254359
# 9485  22.545  88.340 2022-12-30         5.71075      314.481768
# 9486  22.545  88.340 2022-12-31         5.71550      322.851497
#
#       DSWRF_L1_Avg_1  FRICV_L1   GUST_L1     HPBL_L1  LAND_L1  ...  \
# 0         204.350000       NaN  3.826027  301.986018        1  ...
# 1         202.960000       NaN  3.101588  267.144669        1  ...
# 3         202.500000       NaN  2.184178  245.017254        1  ...
# 4         200.550000       NaN  2.317436  244.012100        1  ...
# 5         198.774000       NaN  2.081998  263.980614        1  ...
# ...              ...       ...       ...         ...      ...  ...
# 9482      192.958251  0.239226  3.958173  403.533670        1  ...
# 9483      196.010448  0.293840  4.912187  394.828016        1  ...
# 9484      203.216849  0.245590  3.685035  370.541810        1  ...
# 9485      201.096702  0.158156  2.229730  352.894260        1  ...
# 9486      201.777245  0.156833  2.000811  293.269595        1  ...
#
#       U_GRD_L103  ULWRF_L1_Avg_1  USWRF_L1_Avg_1  V_GRD_L103     VEG_L1  \
# 0       0.177358      421.298931       24.681000   -3.067933        NaN
# 1       0.641507      422.392632       24.658000   -2.350824        NaN
# 3      -0.406643      432.330161       24.274000   -1.479325        NaN
# 4      -0.299777      439.300757       24.093000   -0.909857        NaN
# 5       1.169065      452.033445       23.774000   -0.265803        NaN
# ...          ...             ...             ...         ...        ...
# 9482    2.247126      448.608328       21.978480   -0.238416  18.688000
# 9483    0.292261      437.105191       22.483199   -3.372876  18.658500
# 9484    0.635704      421.643488       23.690880   -2.657268  18.578999
# 9485    0.984448      421.973019       23.313440   -1.411297  18.552000
# 9486    0.452528      432.576161       23.410040   -1.291892  18.479001
#
#             VIS_L1  Station Name      PM 2.5       AOD  PRATE_L1_Avg_1
# 0     24135.001953    Belur Math   77.654583  0.581550    0.000000e+00
# 1     24135.046875    Belur Math   58.124737  0.425139    0.000000e+00
# 3     24134.914062    Belur Math   76.667778  0.415729    0.000000e+00
# 4     24134.949219    Belur Math   92.684583  0.384968    0.000000e+00
# 5     24134.955078    Belur Math  132.424348  0.372209    0.000000e+00
# ...            ...           ...         ...       ...             ...
# 9482  23725.349258      Victoria   69.617500  0.843024    0.000000e+00
# 9483  24134.974609      Victoria  122.754583  0.701000    1.800000e-08
# 9484  24134.886719      Victoria  102.431667  0.626500    0.000000e+00
# 9485  24135.042969      Victoria  135.250833  0.746960    0.000000e+00
# 9486  24135.048828      Victoria  142.677500  0.810233    0.000000e+00
#
# [4160 rows x 26 columns]

# %%
new_df = new_df.drop(['FRICV_L1','LAND_L1','Station Name',"SFC_R_L1","VEG_L1","PRATE_L1_Avg_1","VIS_L1","USWRF_L1_Avg_1","ULWRF_L1_Avg_1","U_GRD_L103"], axis=1)

# %%
# Remove rows with NaN values
new_df= new_df.dropna()

# %%
new_df
# Out:
#          lat     lon       time  ALBDO_L1_Avg_1  DLWRF_L1_Avg_1  \
# 0     22.630  88.352 2021-01-01         5.98142      312.559000
# 1     22.630  88.352 2021-01-02         5.97004      313.683534
# 3     22.630  88.352 2021-01-04         5.91420      333.227000
# 4     22.630  88.352 2021-01-05         5.89578      342.897000
# 5     22.630  88.352 2021-01-06         5.86226      355.172000
# ...      ...     ...        ...             ...             ...
# 9482  22.545  88.340 2022-12-27         5.61565      361.617300
# 9483  22.545  88.340 2022-12-28         5.65195      337.161187
# 9484  22.545  88.340 2022-12-29         5.74805      307.254359
# 9485  22.545  88.340 2022-12-30         5.71075      314.481768
# 9486  22.545  88.340 2022-12-31         5.71550      322.851497
#
#       DSWRF_L1_Avg_1   GUST_L1     HPBL_L1  LHTFL_L1_Avg_1        PRES_L1  \
# 0         204.350000  3.826027  301.986018       30.057888  101429.166812
# 1         202.960000  3.101588  267.144669       30.471104  101373.725500
# 3         202.500000  2.184178  245.017254       29.531700  101243.457063
# 4         200.550000  2.317436  244.012100       30.009221  101231.065125
# 5         198.774000  2.081998  263.980614       28.888099  101035.096312
# ...              ...       ...         ...             ...            ...
# 9482      192.958251  3.958173  403.533670       25.710091  101298.218750
# 9483      196.010448  4.912187  394.828016       29.517080  101423.074531
# 9484      203.216849  3.685035  370.541810       27.342413  101615.603281
# 9485      201.096702  2.229730  352.894260       25.946900  101644.569375
# 9486      201.777245  2.000811  293.269595       22.939286  101607.841719
#
#        R_H_L103  SHTFL_L1_Avg_1    TMP_L103  V_GRD_L103      PM 2.5       AOD
# 0     39.441699       45.322859  293.561722   -3.067933   77.654583  0.581550
# 1     31.246400       43.803595  293.357142   -2.350824   58.124737  0.425139
# 3     41.387301       48.723233  295.297473   -1.479325   76.667778  0.415729
# 4     41.939000       48.853329  296.791448   -0.909857   92.684583  0.384968
# 5     39.217601       45.126278  297.669039   -0.265803  132.424348  0.372209
# ...         ...             ...         ...         ...         ...       ...
# 9482  54.042249       52.806470  297.460245   -0.238416   69.617500  0.843024
# 9483  33.362249       54.177453  295.162292   -3.372876  122.754583  0.701000
# 9484  28.919250       50.784719  293.195768   -2.657268  102.431667  0.626500
# 9485  29.361000       52.307119  293.348338   -1.411297  135.250833  0.746960
# 9486  36.544001       43.616447  294.277830   -1.291892  142.677500  0.810233
#
# [4160 rows x 16 columns]

# %%
# high_pm= df[df['PM 2.5']>30]

# %%
# high_pm

# %%
# Assuming your DataFrame is named 'df'
X = new_df.drop(['PM 2.5',"time","lat","lon"], axis=1)  # Features (excluding the target variable)
y = new_df['PM 2.5']  # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
#print(X_test.dtypes)

# %%
# Create the model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.model_selection import cross_val_score


# Assuming rf_model is your Random Forest model
cross_val_scores = cross_val_score(rf_model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
rmse_cross_val = np.sqrt(-cross_val_scores.mean())

print(f'Cross-Validated RMSE: {rmse_cross_val:.4f}')
# Out:
# Cross-Validated RMSE: 25.5032

# %%
feature_importance = pd.Series(rf_model.feature_importances_, index=X.columns)
feature_importance.sort_values(ascending=False, inplace=True)
print(feature_importance)
# Out:
# DLWRF_L1_Avg_1    0.447287
# ALBDO_L1_Avg_1    0.074940
# R_H_L103          0.065122
# HPBL_L1           0.063988
# GUST_L1           0.061670
# AOD               0.057163
# V_GRD_L103        0.046341
# DSWRF_L1_Avg_1    0.044310
# LHTFL_L1_Avg_1    0.037845
# SHTFL_L1_Avg_1    0.035021
# PRES_L1           0.034234
# TMP_L103          0.032080
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error, r2_score


# Make predictions on the training set
y_train_pred = rf_model.predict(X_train)

# Make predictions on the test set
y_test_pred = rf_model.predict(X_test)

# Calculate RMSE for training and testing sets
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Calculate R-squared for training and testing sets
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

# Display the results
print(f'Training RMSE: {rmse_train:.4f}')
print(f'Testing RMSE: {rmse_test:.4f}')

print(f'Training R-squared: {r2_train:.4f}')
print(f'Testing R-squared: {r2_test:.4f}')
# Out:
# Training RMSE: 9.4831
# Testing RMSE: 24.6394
# Training R-squared: 0.9477
# Testing R-squared: 0.6400

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import numpy as np

# Assuming your data is in a pandas DataFrame named 'new_df1'
# Make sure your 'time' column is in datetime format
new_df1['time'] = pd.to_datetime(new_df1['time'])

# Separate features and target variable
X = new_df1([[]])  # Replace with your actual features
y = new_df1['PM 2.5']

# Create the Random Forest Regressor model
rf_model = RandomForestRegressor()

# Define the hyperparameter grid to search
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Create a grid search object
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, 
                           scoring='neg_mean_squared_error', cv=5, n_jobs=-1)

# Perform the grid search
grid_search.fit(X, y)

# Get the best hyperparameter values
best_params = grid_search.best_params_

# Get the best model
best_rf_model = grid_search.best_estimator_

# Print the best hyperparameter values
print(f'Best Hyperparameters: {best_params}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 10
#       7 new_df1['time'] = pd.to_datetime(new_df1['time'])
#       9 # Separate features and target variable
# ---> 10 X = new_df1.drop(["lat","lon", "time",'FRICV_L1',"PM 2.5",'LAND_L1','Station Name',"SFC_R_L1","VEG_L1","PRATE_L1_Avg_1","VIS_L1","USWRF_L1_Avg_1","ULWRF_L1_Avg_1","U_GRD_L103"])  # Replace with your actual features
#      11 y = new_df1['PM 2.5']
#      13 # Create the Random Forest Regressor model
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['lat', 'lon', 'time', 'FRICV_L1', 'PM 2.5', 'LAND_L1', 'Station Name', 'SFC_R_L1', 'VEG_L1', 'PRATE_L1_Avg_1', 'VIS_L1', 'USWRF_L1_Avg_1', 'ULWRF_L1_Avg_1', 'U_GRD_L103'] not found in axis"

# %%
import joblib

# Save the model to a file
model_filename = 'random_forest_model.pkl'
joblib.dump(rf_model, model_filename)
# Out:
# ['random_forest_model.pkl']

# %% [markdown]
# ready unseen data

# %%
df1= pd.read_excel("Combined All Stations_100m+PM25 added preci.xlsx")

# %%
# df['time'] = pd.to_datetime(df['time'])

# %%
import pandas as pd

# Assuming your data is in a pandas DataFrame named 'df'
# Make sure your 'time' column is in datetime format
df1['time'] = pd.to_datetime(df1['time'])

# Filter data for dates between January 1, 2021, and December 31, 2022
date_range_start = '2022-12-01'
date_range_end = '2022-12-31'
date_mask = (df1['time'] >= date_range_start) & (df1['time'] <= date_range_end)
filtered_data = df1[date_mask]

# Further filter based on 'PM 2.5' range
pm_mask = (filtered_data['PM 2.5'] >= 30) & (filtered_data['PM 2.5'] <= 250)
final_filtered_data = filtered_data[pm_mask]

# Create a new DataFrame with the filtered data
new_df1 = pd.DataFrame(final_filtered_data)

# Display the new DataFrame
print(new_df1)
# Out:
#          lat     lon       time  ALBDO_L1_Avg_1  DLWRF_L1_Avg_1  \
# 699   22.630  88.352 2022-12-01         5.75860      344.459501
# 700   22.630  88.352 2022-12-02         5.84628      323.396785
# 701   22.630  88.352 2022-12-03         5.87226      313.220635
# 702   22.630  88.352 2022-12-04         5.90080      310.218880
# 703   22.630  88.352 2022-12-05         5.91238      312.582410
# ...      ...     ...        ...             ...             ...
# 9482  22.545  88.340 2022-12-27         5.61565      361.617300
# 9483  22.545  88.340 2022-12-28         5.65195      337.161187
# 9484  22.545  88.340 2022-12-29         5.74805      307.254359
# 9485  22.545  88.340 2022-12-30         5.71075      314.481768
# 9486  22.545  88.340 2022-12-31         5.71550      322.851497
#
#       DSWRF_L1_Avg_1  FRICV_L1   GUST_L1     HPBL_L1  LAND_L1  ...  \
# 699       203.826680  0.265106  4.726225  385.233757        1  ...
# 700       208.832862  0.237866  3.650794  330.169966        1  ...
# 701       209.505118  0.222924  3.378228  292.294800        1  ...
# 702       210.874794  0.247803  3.922807  285.950660        1  ...
# 703       209.972613  0.245097  3.854051  298.568408        1  ...
# ...              ...       ...       ...         ...      ...  ...
# 9482      192.958251  0.239226  3.958173  403.533670        1  ...
# 9483      196.010448  0.293840  4.912187  394.828016        1  ...
# 9484      203.216849  0.245590  3.685035  370.541810        1  ...
# 9485      201.096702  0.158156  2.229730  352.894260        1  ...
# 9486      201.777245  0.156833  2.000811  293.269595        1  ...
#
#       U_GRD_L103  ULWRF_L1_Avg_1  USWRF_L1_Avg_1  V_GRD_L103     VEG_L1  \
# 699     0.267449      441.925509       23.923216   -3.496315  27.414800
# 700     0.481890      432.075243       24.877200   -3.187829  26.899400
# 701     0.500028      426.097032       25.062207   -2.962007  26.371801
# 702     0.808684      423.687867       25.349631   -3.231959  25.871200
# 703     0.926648      424.930613       25.251408   -3.183305  25.364000
# ...          ...             ...             ...         ...        ...
# 9482    2.247126      448.608328       21.978480   -0.238416  18.688000
# 9483    0.292261      437.105191       22.483199   -3.372876  18.658500
# 9484    0.635704      421.643488       23.690880   -2.657268  18.578999
# 9485    0.984448      421.973019       23.313440   -1.411297  18.552000
# 9486    0.452528      432.576161       23.410040   -1.291892  18.479001
#
#             VIS_L1  Station Name      PM 2.5       AOD  PRATE_L1_Avg_1
# 699   24134.984375    Belur Math   79.773478  0.337600    0.000000e+00
# 700   24135.054688    Belur Math   95.232917  0.642600    0.000000e+00
# 701   24135.007812    Belur Math  107.005455  0.574832    0.000000e+00
# 702   24135.070312    Belur Math  104.317083  0.617600    0.000000e+00
# 703   24134.796875    Belur Math  101.612609  0.746300    0.000000e+00
# ...            ...           ...         ...       ...             ...
# 9482  23725.349258      Victoria   69.617500  0.843024    0.000000e+00
# 9483  24134.974609      Victoria  122.754583  0.701000    1.800000e-08
# 9484  24134.886719      Victoria  102.431667  0.626500    0.000000e+00
# 9485  24135.042969      Victoria  135.250833  0.746960    0.000000e+00
# 9486  24135.048828      Victoria  142.677500  0.810233    0.000000e+00
#
# [308 rows x 26 columns]

# %%
new_df1= new_df1.dropna()

# %%
X_unseen = new_df1.drop(['PM 2.5','FRICV_L1','LAND_L1','Station Name',"time","lat","lon","VEG_L1","SFC_R_L1","PRATE_L1_Avg_1","VIS_L1","USWRF_L1_Avg_1","ULWRF_L1_Avg_1","U_GRD_L103"], axis=1)  # Features (excluding the target variable)

# %%
# Later, when you want to use the model for predictions on unseen data:
# Load the model from the file
import joblib
loaded_model = joblib.load(model_filename)

#Make predictions on unseen data (replace X_unseen with your actual unseen data)
y_unseen_pred = loaded_model.predict(X_unseen)

#Display the predictions on unseen data
print(y_unseen_pred)
pm=(new_df1["PM 2.5"])
# Out:
# [ 82.1666354  106.16148727 118.81083493 125.14031418 114.46493134
#  106.70099237 121.44607171 117.64848876 118.00323481 113.05622391
#  125.50374583 140.10141835 155.72059272 140.95591517 123.80074562
#  101.63694558 143.18103179 151.95252867 149.32229771 139.31449164
#  152.31096809 225.76534036 131.25754213 170.9581374   98.03960704
#   79.08834972  83.81826828 105.38085468  89.54882319 124.52044212
#  160.06935424  83.31543574 142.18122888 173.05691578 131.66539106
#  140.65221882 141.73419767 156.76096591 149.23405138 124.09488247
#  137.90495059 127.95134378 182.80852292 152.49889119 182.87477414
#  151.56306899 183.23935013 156.96916783 145.251685   144.93939119
#  231.91009482 175.42785209 205.3224683   91.44410853  72.78069384
#   88.59446779 130.28237195  96.48233657 122.54364357 165.21658109
#   75.50116108 105.35359523 102.31242954  90.75515707  97.38632422
#   86.53654583 110.11533183 112.35981301 102.77853712 101.99182772
#  115.10988759 128.28517715 124.31478878 122.02007105 113.75047982
#   79.15871169  96.52007205 131.79646003 117.27905004 134.70890769
#  132.5161784  147.52191051 139.23604523 143.93756981  78.64188687
#   52.6097368   64.33422004  96.27351633  98.3085898  114.79560809
#  124.94723577  87.71450833 123.24072455 110.21299619  96.63206108
#  102.33351131  86.10512302 120.68204999 135.1566804  116.0193476
#   81.93135551 129.92227085 109.77046187 149.7898767  145.86952662
#  103.50906054 101.41550227 138.88957515 160.36227877 118.44707719
#  148.54774691 146.59639136 146.9676072  111.63745283 137.00563252
#   89.02403029  44.21560096  72.29348913  98.68308244  86.47766816
#  115.93103587 120.89183388  84.30504924 122.78376014 123.60478923
#  119.66551344 125.56838219 110.59459252 135.77668063 133.2578391
#  113.10631439 124.62578319 142.47484947 156.1174263  151.86301458
#  161.23033149 137.28102105 116.01694348 143.52651387 166.05449571
#  150.99255848 151.86995183 144.28589609 210.8448207  137.37883811
#  165.19800172 112.41540634  77.33240536  76.58726866 125.594124
#  104.41115985 138.61631918 157.61959803  67.13688678 120.62612289
#  109.77779636  95.64623707  86.17166594  75.22652548  93.4930812
#  138.79156186  85.60168949  80.45182759  95.83155819  98.0991713
#  109.88587174 148.08611373  91.43488007  83.04861584  96.21588972
#  150.09862782 100.60484649 144.74619573 147.50820083 152.27876897
#  105.4802601  156.18267747  86.55177217  39.71400725  71.41173884
#   98.78577871  73.58368221  98.02143147 108.17127524  94.08641039
#  109.07201602 108.33687706 122.50407027 119.42650115  93.19781336
#  133.8810831  135.32495207 128.6633654   85.27178556 129.56342275
#  141.88396252 135.74067355 146.44824238 119.39887041  99.62017124
#  117.90219158 124.09164445 118.38390585 140.60401192 150.0539556
#  138.6839466  147.9182091  130.1343885   80.93031214  46.19972984
#   68.27888527 102.14051757  91.4657194  117.86473124 119.81745417
#   83.53768029 113.09587572 119.00666505 116.95072558 125.45885506
#  110.60978137 129.81284661 142.57492137 136.67385069 128.34722482
#  144.82086257 159.76391444 155.85780749 128.88845974 101.51100145
#  104.33085334 152.74346922 155.36307373 149.90774919 146.80816096
#  156.37783275 216.44838618 147.84493677 162.0381138   93.4169211
#   83.41541069  80.41545586 124.29417511 112.10839895 137.68270392
#  157.12259432  86.99819098 104.51082514 105.96750433  99.8020804
#  110.86705253  88.80222599 119.11891848 129.29454086 105.87002166
#   88.79977576 107.6265875  137.31178661 116.77648918 121.23302632
#   89.95696413  95.87826966 100.67527617 121.88454819 117.89848155
#  134.21338754 128.84250393 135.81259805 114.68503227 126.43311586
#   70.42910652  42.83478763  67.59257879  90.59254269  83.24937997
#  111.63983802 118.87966537  78.16847477 120.97550932 105.6691603
#  103.38390542 105.42570334  85.2265403  110.75041026 143.90427665
#  134.52538171  83.30204244 141.45669951 117.78088472 128.08282625
#  178.85668636 127.17340049  88.23361299 125.93564979 138.12514571
#  127.74825718 138.9123393  142.61304814 148.01949284 111.04077693
#  160.88917224  74.3307962   44.99898363  69.11443223  96.55668057
#   81.06807525 107.46005861 120.41504881]

# %%
rmse = np.sqrt(mean_squared_error(y_unseen_pred, pm))

# %%
rmse
# Out:
# 25.148228244287417

# %%
r2_unseen = r2_score(y_unseen_pred, pm)

# %%
r2_unseen
# Out:
# 0.313055000748643

# %%
import matplotlib.pyplot as plt

# Assuming 'time' is the x-axis and 'PM 2.5' is the y-axis
time_series = new_df1['time']
pm_values = new_df1['PM 2.5']

# Plot the line graph
plt.figure(figsize=(10, 6))
plt.plot(time_series, pm_values, label='PM 2.5', marker='o', linestyle='-', color='b')

# Set labels and title
plt.xlabel('Time')
plt.ylabel('PM 2.5 Values')
plt.title('PM 2.5 Values Over Time')

# Display legend
plt.legend()

# Show the plot
plt.show()
