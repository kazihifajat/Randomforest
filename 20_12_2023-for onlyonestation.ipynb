# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# %%
df= pd.read_csv("only_variable_with_corr_name_season_added.csv")

# %%
df
# Out:
#       Latitude  Longitude        Time    Albedo  Downward_Long-Wave_Rad_Flux  \
# 0       22.630     88.352  2021-01-01   5.98142                   312.559000
# 1       22.630     88.352  2021-01-02   5.97004                   313.683534
# 2       22.630     88.352  2021-01-03   5.93766                   322.803813
# 3       22.630     88.352  2021-01-04   5.91420                   333.227000
# 4       22.630     88.352  2021-01-05   5.89578                   342.897000
# ...        ...        ...         ...       ...                          ...
# 9725    22.545     88.340  2023-08-27  11.06430                   447.360698
# 9726    22.545     88.340  2023-08-28  11.38305                   446.798837
# 9727    22.545     88.340  2023-08-29  11.53260                   449.412098
# 9728    22.545     88.340  2023-08-30  11.89660                   444.362351
# 9729    22.545     88.340  2023-08-31  11.06580                   449.656999
#
#       Downward_Short-Wave_Rad_Flux  Wind_Gust  \
# 0                       204.350000   3.826027
# 1                       202.960000   3.101588
# 2                       195.740000   2.774223
# 3                       202.500000   2.184178
# 4                       200.550000   2.317436
# ...                            ...        ...
# 9725                    218.351436   4.011113
# 9726                    254.572562   3.222736
# 9727                    170.017404   2.810299
# 9728                    238.533522   2.842451
# 9729                    214.339204   3.711203
#
#       Planetary_Boundary_Layer_Height  Latent_Heat_Flux       Pressure  ...  \
# 0                          301.986018         30.057888  101429.166812  ...
# 1                          267.144669         30.471104  101373.725500  ...
# 2                          262.226417         28.723234  101257.671000  ...
# 3                          245.017254         29.531700  101243.457063  ...
# 4                          244.012100         30.009221  101231.065125  ...
# ...                               ...               ...            ...  ...
# 9725                       509.447365        121.838930  100109.151406  ...
# 9726                       348.428543        132.334216  100105.622344  ...
# 9727                       586.165287         94.150990  100182.874219  ...
# 9728                       508.752148        110.109848  100287.627813  ...
# 9729                       551.716328         97.653867  100346.506719  ...
#
#       Cosine_of_Month  weekday  oct_feb  march_may  june_sep  nov_feb  \
# 0            0.866025        1        1          0         0        1
# 1            0.866025        1        1          0         0        1
# 2            0.866025        0        1          0         0        1
# 3            0.866025        1        1          0         0        1
# 4            0.866025        1        1          0         0        1
# ...               ...      ...      ...        ...       ...      ...
# 9725        -0.500000        0        0          0         1        0
# 9726        -0.500000        1        0          0         1        0
# 9727        -0.500000        1        0          0         1        0
# 9728        -0.500000        1        0          0         1        0
# 9729        -0.500000        1        0          0         1        0
#
#       june_aug  sep_oct nov_march  april_may
# 0            0        0         1          0
# 1            0        0         1          0
# 2            0        0         1          0
# 3            0        0         1          0
# 4            0        0         1          0
# ...        ...      ...       ...        ...
# 9725         1        0         0          0
# 9726         1        0         0          0
# 9727         1        0         0          0
# 9728         1        0         0          0
# 9729         1        0         0          0
#
# [9730 rows x 33 columns]

# %%
#station_name = 'Belur Math'  # Replace 'YourStationName' with the actual station name
#selected_data = df[df['Station Name'] == station_name]

# %%
#selected_data

# %%
#df=selected_data

# %%
nan_count_per_column = df.isna().sum()

print("Number of NaN values in each column:")
print(nan_count_per_column)
# Out:
# Number of NaN values in each column:
# Latitude                             0
# Longitude                            0
# Time                                 0
# Albedo                               0
# Downward_Long-Wave_Rad_Flux          0
# Downward_Short-Wave_Rad_Flux         0
# Wind_Gust                            0
# Planetary_Boundary_Layer_Height      0
# Latent_Heat_Flux                     0
# Pressure                             0
# R_H_L103                             0
# SHTFL_L1_Avg_1                       0
# TMP_L103                             0
# U_GRD_L103                           0
# ULWRF_L1_Avg_1                       0
# USWRF_L1_Avg_1                       0
# Vertical_motion                      0
# Visibility                           0
# Station Name                         0
# PM 2.5                             225
# AOD                                  0
# Precipitation_Rate                   0
# Sine_of_Month                        0
# Cosine_of_Month                      0
# weekday                              0
# oct_feb                              0
# march_may                            0
# june_sep                             0
# nov_feb                              0
# june_aug                             0
# sep_oct                              0
# nov_march                            0
# april_may                            0
# dtype: int64

# %%
# Forward fill
#df['AOD'] = df['AOD'].fillna(method='ffill')

# Backward fill
#df['AOD'] = df['AOD'].fillna(method='bfill')
import pandas as pd

# Assuming df is your DataFrame
#df['AOD'] = df['AOD'].ffill()
#df['PM 2.5'] = df['PM 2.5'].ffill()

# Or, if you want to use backward filling (bfill) instead:
# df['AOD'] = df['AOD'].bfill()

# %%
nan_count_per_column = df.isna().sum()

print("Number of NaN values in each column:")
print(nan_count_per_column)
# Out:
# Number of NaN values in each column:
# Latitude                             0
# Longitude                            0
# Time                                 0
# Albedo                               0
# Downward_Long-Wave_Rad_Flux          0
# Downward_Short-Wave_Rad_Flux         0
# Wind_Gust                            0
# Planetary_Boundary_Layer_Height      0
# Latent_Heat_Flux                     0
# Pressure                             0
# R_H_L103                             0
# SHTFL_L1_Avg_1                       0
# TMP_L103                             0
# U_GRD_L103                           0
# ULWRF_L1_Avg_1                       0
# USWRF_L1_Avg_1                       0
# Vertical_motion                      0
# Visibility                           0
# Station Name                         0
# PM 2.5                             225
# AOD                                  0
# Precipitation_Rate                   0
# Sine_of_Month                        0
# Cosine_of_Month                      0
# weekday                              0
# oct_feb                              0
# march_may                            0
# june_sep                             0
# nov_feb                              0
# june_aug                             0
# sep_oct                              0
# nov_march                            0
# april_may                            0
# dtype: int64

# %%
df['Time'] = pd.to_datetime(df['Time'])

# %% [raw]
# # import numpy as np
#
# df['sin_month'] = np.sin(2 * np.pi * df['Time'].dt.month / 12)
# df['cos_month'] = np.cos(2 * np.pi * df['Time'].dt.month / 12)

# %%
# Assuming your data is in a pandas DataFrame named 'df'
# Make sure your 'Time' column is in dateTime format
df['Time'] = pd.to_datetime(df['Time'])

# Filter data for dates between January 1, 2021, and December 31, 2022
date_range_start = '2021-01-01'
date_range_end = '2022-11-30'
date_mask = (df['Time'] >= date_range_start) & (df['Time'] <= date_range_end)
filtered_data = df[date_mask]

# Further filter based on 'PM 2.5' range
pm_mask = (filtered_data['PM 2.5'] >= 30) & (filtered_data['PM 2.5'] <= 200)
final_filtered_data = filtered_data[pm_mask]

# Create a new DataFrame with the filtered data
new_df = pd.DataFrame(final_filtered_data)

# Display the new DataFrame
print(new_df)
# Out:
#       Latitude  Longitude       Time   Albedo  Downward_Long-Wave_Rad_Flux  \
# 0       22.630     88.352 2021-01-01  5.98142                   312.559000
# 1       22.630     88.352 2021-01-02  5.97004                   313.683534
# 3       22.630     88.352 2021-01-04  5.91420                   333.227000
# 4       22.630     88.352 2021-01-05  5.89578                   342.897000
# 5       22.630     88.352 2021-01-06  5.86226                   355.172000
# ...        ...        ...        ...      ...                          ...
# 9451    22.545     88.340 2022-11-26  5.68390                   333.394346
# 9452    22.545     88.340 2022-11-27  5.68290                   334.095646
# 9453    22.545     88.340 2022-11-28  5.64940                   341.222578
# 9454    22.545     88.340 2022-11-29  5.54430                   368.164877
# 9455    22.545     88.340 2022-11-30  7.29460                   372.581345
#
#       Downward_Short-Wave_Rad_Flux  Wind_Gust  \
# 0                       204.350000   3.826027
# 1                       202.960000   3.101588
# 3                       202.500000   2.184178
# 4                       200.550000   2.317436
# 5                       198.774000   2.081998
# ...                            ...        ...
# 9451                    212.752595   3.006576
# 9452                    211.610745   2.565543
# 9453                    208.738902   2.989004
# 9454                    199.690645   3.528009
# 9455                    222.966853   3.830518
#
#       Planetary_Boundary_Layer_Height  Latent_Heat_Flux       Pressure  ...  \
# 0                          301.986018         30.057888  101429.166812  ...
# 1                          267.144669         30.471104  101373.725500  ...
# 3                          245.017254         29.531700  101243.457063  ...
# 4                          244.012100         30.009221  101231.065125  ...
# 5                          263.980614         28.888099  101035.096312  ...
# ...                               ...               ...            ...  ...
# 9451                       353.161592         44.043686  101004.312656  ...
# 9452                       406.359686         41.616214  100886.430156  ...
# 9453                       378.695635         41.007530  101021.260469  ...
# 9454                       367.272639         42.218011  101125.302344  ...
# 9455                       364.536606         48.145430  101178.925469  ...
#
#       Cosine_of_Month  weekday  oct_feb  march_may  june_sep  nov_feb  \
# 0            0.866025        1        1          0         0        1
# 1            0.866025        1        1          0         0        1
# 3            0.866025        1        1          0         0        1
# 4            0.866025        1        1          0         0        1
# 5            0.866025        1        1          0         0        1
# ...               ...      ...      ...        ...       ...      ...
# 9451         0.866025        1        1          0         0        1
# 9452         0.866025        0        1          0         0        1
# 9453         0.866025        1        1          0         0        1
# 9454         0.866025        1        1          0         0        1
# 9455         0.866025        1        1          0         0        1
#
#       june_aug  sep_oct nov_march  april_may
# 0            0        0         1          0
# 1            0        0         1          0
# 3            0        0         1          0
# 4            0        0         1          0
# 5            0        0         1          0
# ...        ...      ...       ...        ...
# 9451         0        0         1          0
# 9452         0        0         1          0
# 9453         0        0         1          0
# 9454         0        0         1          0
# 9455         0        0         1          0
#
# [3810 rows x 33 columns]

# %%
new_df = new_df.drop(['Station Name'], axis=1)

# %%
# Remove rows with NaN values
new_df= new_df.dropna()

# %%
new_df
# Out:
#       Latitude  Longitude       Time   Albedo  Downward_Long-Wave_Rad_Flux  \
# 0       22.630     88.352 2021-01-01  5.98142                   312.559000
# 1       22.630     88.352 2021-01-02  5.97004                   313.683534
# 3       22.630     88.352 2021-01-04  5.91420                   333.227000
# 4       22.630     88.352 2021-01-05  5.89578                   342.897000
# 5       22.630     88.352 2021-01-06  5.86226                   355.172000
# ...        ...        ...        ...      ...                          ...
# 9451    22.545     88.340 2022-11-26  5.68390                   333.394346
# 9452    22.545     88.340 2022-11-27  5.68290                   334.095646
# 9453    22.545     88.340 2022-11-28  5.64940                   341.222578
# 9454    22.545     88.340 2022-11-29  5.54430                   368.164877
# 9455    22.545     88.340 2022-11-30  7.29460                   372.581345
#
#       Downward_Short-Wave_Rad_Flux  Wind_Gust  \
# 0                       204.350000   3.826027
# 1                       202.960000   3.101588
# 3                       202.500000   2.184178
# 4                       200.550000   2.317436
# 5                       198.774000   2.081998
# ...                            ...        ...
# 9451                    212.752595   3.006576
# 9452                    211.610745   2.565543
# 9453                    208.738902   2.989004
# 9454                    199.690645   3.528009
# 9455                    222.966853   3.830518
#
#       Planetary_Boundary_Layer_Height  Latent_Heat_Flux       Pressure  ...  \
# 0                          301.986018         30.057888  101429.166812  ...
# 1                          267.144669         30.471104  101373.725500  ...
# 3                          245.017254         29.531700  101243.457063  ...
# 4                          244.012100         30.009221  101231.065125  ...
# 5                          263.980614         28.888099  101035.096312  ...
# ...                               ...               ...            ...  ...
# 9451                       353.161592         44.043686  101004.312656  ...
# 9452                       406.359686         41.616214  100886.430156  ...
# 9453                       378.695635         41.007530  101021.260469  ...
# 9454                       367.272639         42.218011  101125.302344  ...
# 9455                       364.536606         48.145430  101178.925469  ...
#
#       Cosine_of_Month  weekday  oct_feb  march_may  june_sep  nov_feb  \
# 0            0.866025        1        1          0         0        1
# 1            0.866025        1        1          0         0        1
# 3            0.866025        1        1          0         0        1
# 4            0.866025        1        1          0         0        1
# 5            0.866025        1        1          0         0        1
# ...               ...      ...      ...        ...       ...      ...
# 9451         0.866025        1        1          0         0        1
# 9452         0.866025        0        1          0         0        1
# 9453         0.866025        1        1          0         0        1
# 9454         0.866025        1        1          0         0        1
# 9455         0.866025        1        1          0         0        1
#
#       june_aug  sep_oct  nov_march  april_may
# 0            0        0          1          0
# 1            0        0          1          0
# 3            0        0          1          0
# 4            0        0          1          0
# 5            0        0          1          0
# ...        ...      ...        ...        ...
# 9451         0        0          1          0
# 9452         0        0          1          0
# 9453         0        0          1          0
# 9454         0        0          1          0
# 9455         0        0          1          0
#
# [3810 rows x 32 columns]

# %%
# high_pm= df[df['PM 2.5']>30]

# %%
# high_pm

# %%
# Assuming your DataFrame is named 'df'
X = new_df.drop(['PM 2.5',"Time","Downward_Long-Wave_Rad_Flux"], axis=1)  # Features (excluding the target variable)
y = new_df['PM 2.5']  # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#print(X_test.dtypes)

# %%
# Create the model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.model_selection import cross_val_score


# Assuming rf_model is your Random Forest model
cross_val_scores = cross_val_score(rf_model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
rmse_cross_val = np.sqrt(-cross_val_scores.mean())

print(f'Cross-Validated RMSE: {rmse_cross_val:.4f}')
# Out:
# Cross-Validated RMSE: 16.4892

# %%
feature_importance = pd.Series(rf_model.feature_importances_, index=X.columns)
feature_importance.sort_values(ascending=False, inplace=True)
print(feature_importance)
# Out:
# nov_feb                            0.336701
# R_H_L103                           0.147067
# Latitude                           0.123262
# Latent_Heat_Flux                   0.060105
# AOD                                0.047143
# Wind_Gust                          0.032216
# Albedo                             0.029821
# nov_march                          0.029111
# Vertical_motion                    0.024717
# TMP_L103                           0.023417
# Downward_Short-Wave_Rad_Flux       0.017518
# SHTFL_L1_Avg_1                     0.017147
# Pressure                           0.016819
# Planetary_Boundary_Layer_Height    0.015986
# Longitude                          0.015797
# ULWRF_L1_Avg_1                     0.014454
# Visibility                         0.014074
# U_GRD_L103                         0.013562
# USWRF_L1_Avg_1                     0.011262
# Precipitation_Rate                 0.004549
# Cosine_of_Month                    0.001743
# Sine_of_Month                      0.001632
# weekday                            0.001143
# oct_feb                            0.000669
# june_sep                           0.000034
# april_may                          0.000018
# sep_oct                            0.000012
# june_aug                           0.000010
# march_may                          0.000010
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error, r2_score


# Make predictions on the training set
y_train_pred = rf_model.predict(X_train)

# Make predictions on the test set
y_test_pred = rf_model.predict(X_test)

# Calculate RMSE for training and testing sets
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Calculate R-squared for training and testing sets
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

# Display the results
print(f'Training RMSE: {rmse_train:.4f}')
print(f'Testing RMSE: {rmse_test:.4f}')

print(f'Training R-squared: {r2_train:.4f}')
print(f'Testing R-squared: {r2_test:.4f}')
# Out:
# Training RMSE: 5.8596
# Testing RMSE: 16.3424
# Training R-squared: 0.9754
# Testing R-squared: 0.8030

# %%
import joblib

# Save the model to a file
model_filename = 'random_forest_model_28.pkl'
joblib.dump(rf_model, model_filename)
# Out:
# ['random_forest_model_28.pkl']

# %% [markdown]
# ready unseen data

# %%
df1= pd.read_csv("only_variable_with_corr_name_season_added.csv")

# %% [raw]
# # df['Time'] = pd.to_dateTime(df['Time'])
# station_name = 'Belur Math'  # Replace 'YourStationName' with the actual station name
# selected_data = df1[df1['Station Name'] == station_name]
# df1=selected_data

# %%
import pandas as pd

# Assuming your data is in a pandas DataFrame named 'df'
# Make sure your 'Time' column is in dateTime format
df1['Time'] = pd.to_datetime(df1['Time'])

# Filter data for dates between January 1, 2021, and December 31, 2022
date_range_start = '2022-12-01'
date_range_end = '2022-12-31'
date_mask = (df1['Time'] >= date_range_start) & (df1['Time'] <= date_range_end)
filtered_data = df1[date_mask]

# Further filter based on 'PM 2.5' range
#pm_mask = (filtered_data['PM 2.5'] >= 30) & (filtered_data['PM 2.5'] <= 250)
pm_mask = (filtered_data['PM 2.5'] >= 30) & (filtered_data['PM 2.5'] <= 200)
final_filtered_data = filtered_data[pm_mask]


# Create a new DataFrame with the filtered data
new_df1 = pd.DataFrame(final_filtered_data)

# Display the new DataFrame
print(new_df1)
# Out:
#       Latitude  Longitude       Time   Albedo  Downward_Long-Wave_Rad_Flux  \
# 699     22.630     88.352 2022-12-01  5.75860                   344.459501
# 700     22.630     88.352 2022-12-02  5.84628                   323.396785
# 701     22.630     88.352 2022-12-03  5.87226                   313.220635
# 702     22.630     88.352 2022-12-04  5.90080                   310.218880
# 703     22.630     88.352 2022-12-05  5.91238                   312.582410
# ...        ...        ...        ...      ...                          ...
# 9482    22.545     88.340 2022-12-27  5.61565                   361.617300
# 9483    22.545     88.340 2022-12-28  5.65195                   337.161187
# 9484    22.545     88.340 2022-12-29  5.74805                   307.254359
# 9485    22.545     88.340 2022-12-30  5.71075                   314.481768
# 9486    22.545     88.340 2022-12-31  5.71550                   322.851497
#
#       Downward_Short-Wave_Rad_Flux  Wind_Gust  \
# 699                     203.826680   4.726225
# 700                     208.832862   3.650794
# 701                     209.505118   3.378228
# 702                     210.874794   3.922807
# 703                     209.972613   3.854051
# ...                            ...        ...
# 9482                    192.958251   3.958173
# 9483                    196.010448   4.912187
# 9484                    203.216849   3.685035
# 9485                    201.096702   2.229730
# 9486                    201.777245   2.000811
#
#       Planetary_Boundary_Layer_Height  Latent_Heat_Flux       Pressure  ...  \
# 699                        385.233757         51.261566  101122.673500  ...
# 700                        330.169966         48.614990  101132.043188  ...
# 701                        292.294800         48.357051  101171.169625  ...
# 702                        285.950660         49.196884  101222.227813  ...
# 703                        298.568408         46.708963  101269.753125  ...
# ...                               ...               ...            ...  ...
# 9482                       403.533670         25.710091  101298.218750  ...
# 9483                       394.828016         29.517080  101423.074531  ...
# 9484                       370.541810         27.342413  101615.603281  ...
# 9485                       352.894260         25.946900  101644.569375  ...
# 9486                       293.269595         22.939286  101607.841719  ...
#
#       Cosine_of_Month  weekday  oct_feb  march_may  june_sep  nov_feb  \
# 699               1.0        1        1          0         0        1
# 700               1.0        1        1          0         0        1
# 701               1.0        1        1          0         0        1
# 702               1.0        0        1          0         0        1
# 703               1.0        1        1          0         0        1
# ...               ...      ...      ...        ...       ...      ...
# 9482              1.0        1        1          0         0        1
# 9483              1.0        1        1          0         0        1
# 9484              1.0        1        1          0         0        1
# 9485              1.0        1        1          0         0        1
# 9486              1.0        1        1          0         0        1
#
#       june_aug  sep_oct nov_march  april_may
# 699          0        0         1          0
# 700          0        0         1          0
# 701          0        0         1          0
# 702          0        0         1          0
# 703          0        0         1          0
# ...        ...      ...       ...        ...
# 9482         0        0         1          0
# 9483         0        0         1          0
# 9484         0        0         1          0
# 9485         0        0         1          0
# 9486         0        0         1          0
#
# [294 rows x 33 columns]

# %%
new_df1= new_df1.dropna()

# %%
X_unseen = new_df1.drop(['PM 2.5','Station Name',"Time","Downward_Long-Wave_Rad_Flux"], axis=1)  # Features (excluding the target variable)

# %%
# Later, when you want to use the model for predictions on unseen data:
# Load the model from the file
import joblib
loaded_model = joblib.load(model_filename)

#Make predictions on unseen data (replace X_unseen with your actual unseen data)
y_unseen_pred = loaded_model.predict(X_unseen)

#Display the predictions on unseen data
print(y_unseen_pred)
pm=(new_df1["PM 2.5"])
print(pm)
# Out:
# [ 84.9036312  105.19021442 105.41085191 105.50282404 115.11454862
#  108.55197119 116.2741422   93.89661688 103.16495063  88.92623047
#  109.06066127 107.83713463 105.01028643 112.17445881  89.71313026
#   84.95450082 111.34280797 111.887864   114.41434685 112.93549416
#  111.08458638  92.14461477 105.62750025 103.0602039  100.19531589
#  102.32264833 109.89389216 100.87404859 115.44091539 122.72934707
#  131.2173931  154.31848297 156.15928659 155.63939291 149.34201209
#  154.4570217  153.58993927 153.72651628 139.34449107 154.94973707
#  141.76025437 153.00486491 146.07274002 145.38198598 141.53126878
#  152.95775513 156.02125716 157.79052695 159.65791218  75.84525763
#   84.46889649 100.93669705  99.58782362 104.81716111  98.33951829
#  111.65105002 121.84257189 106.84650528 103.46927986 129.26312844
#  119.19230497 119.08373874 119.63942011 105.20128645 108.90330683
#  124.65714525 146.97597714 142.3600505  144.52335316 142.11961252
#  152.97015831 126.20284359 141.94405143 109.52832149 116.11428198
#   94.77898373 122.77964385 124.8927451  141.83862082 153.58375682
#   73.5904749  118.40640018 112.45446089  89.44904964 121.69250273
#  108.3679619  116.27951343 101.32171185 106.63009784  95.61402089
#  118.8784835  117.40626977 112.1113313  118.19897079  98.18401564
#   90.78581311 127.94758887 121.93503427 117.24102564 124.94946429
#  126.33212699 136.50708544 115.38571664 130.44447009 116.00107277
#  111.16670268 108.86719365 113.22401441 133.19973782 126.20068992
#  135.60831757  83.94620953 118.79325673 113.63728354  88.99730155
#  121.92915852 114.56752985 114.55551301  96.41938935  92.33192797
#   95.73635169 117.69748751 117.48908628 111.73183289 118.48278328
#  106.42344794  85.60228829 116.69561503 114.73402972 107.35080937
#  121.00861823 119.71395846 102.09292081 122.72523526  90.68524208
#  104.90799733 108.40858938 106.79631344 113.40769365 115.25618528
#  122.93393835  71.18736697 104.55986565 103.84596226 106.66740788
#  106.8745089  100.64733359 100.48807139 101.84092604 102.09625545
#   96.45516439 110.33877513 111.26292411 109.6861255  107.92165586
#   95.64845085  88.75120937 115.89570423 120.50867767 116.98289362
#  119.80575444 121.19009651 134.71140869 116.24036469 123.00608517
#  109.98192324 107.68185237 100.48103422 105.92035402 119.08448318
#  125.15456634 135.31679346  87.48409516 113.79465377 105.95094946
#  112.53693391 118.26995761 109.35325578 121.14611544 104.73573549
#  103.30656505  94.10947023 119.02942588 116.5874747  113.50449476
#  116.99173179  98.33705661  92.33223804 125.35407262 123.84411937
#  120.39575242 124.36245911 128.79905534 140.7122629  130.57720624
#  125.51996846  90.26583843 112.43431525 109.24463083 113.19670571
#  132.28631926 123.54637701 144.19456534 112.19604998 154.68742447
#  149.87970439 141.51607331 159.32663231 152.39687824 153.93024941
#  151.97873892 158.31058148 138.58534669 148.51078084 160.83841909
#  156.99041628 159.14291251 137.61540694 139.27105919 165.7900647
#  161.98036006 154.8714142  161.4370665  156.53491927 157.41625371
#  154.87944723 158.4279265  145.87786201 151.06910225 152.49767325
#  157.22065536 158.12534096 166.89044519 163.04271295  73.79483635
#  100.45959279  98.56539429  82.77085725 106.11674637  95.47710214
#  106.279401   104.81232702  96.9663763   92.76601102 109.95171974
#  110.40847395 110.66457234 105.33168279  92.91660236  94.36109486
#  112.82693381 120.21858362 122.64638591 118.64021856 121.5299117
#  141.21440188 109.43478061 123.94116685 108.05234832 104.34289711
#  101.87513005 109.40530266 113.09820132 123.15988645 142.67910775
#   74.23278532 103.80212683 102.38219752 104.87610682 106.20841058
#  103.46919836 104.7935213  111.1040456   96.15138298  96.80315307
#  113.12820498 111.75877215  94.89039958  88.74964916 115.09902381
#  118.62419683 117.01945707 119.761233   124.11566104 140.2426887
#  117.07282249 123.85021913 107.83511599 106.45261852  99.50562507
#  107.4780092  121.91637488 123.74170578 137.54595673]
# 699      79.773478
# 700      95.232917
# 701     107.005455
# 702     104.317083
# 703     101.612609
#            ...
# 9482     69.617500
# 9483    122.754583
# 9484    102.431667
# 9485    135.250833
# 9486    142.677500
# Name: PM 2.5, Length: 294, dtype: float64

# %%
rmse = np.sqrt(mean_squared_error(y_unseen_pred, pm))

# %%
rmse
# Out:
# 32.34174226636827

# %%
r2_unseen = r2_score(y_unseen_pred, pm)

# %%
r2_unseen
# Out:
# -1.4608630913268246

# %%
import numpy as np

# Assuming y_unseen_pred and pm_actual are your predicted and actual PM 2.5 values
correlation_coefficient = np.corrcoef(y_unseen_pred, pm)[0, 1]

print(f'Correlation coefficient between predicted and actual PM 2.5: {correlation_coefficient:.4f}')
# Out:
# Correlation coefficient between predicted and actual PM 2.5: 0.4088

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Assuming y_actual and y_pred are your actual and predicted values
y_actual_tttt = np.array([pm])  # Replace with your actual values
y_pred_tttt = np.array([y_unseen_pred])  # Replace with your predicted values

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_actual_tttt, y_pred_tttt))

# Calculate the mean of the target variable
mean_target = np.mean(y_actual_tttt)

# Compare RMSE with Mean
print(f'RMSE: {rmse:.4f}')
print(f'Mean of the Target Variable: {mean_target:.4f}')

# Normalize RMSE by dividing by the mean
nrmse = rmse / mean_target
print(f'Normalized RMSE (NRMSE): {nrmse:.4f}')
# Out:
# RMSE: 32.3417
# Mean of the Target Variable: 116.5105
# Normalized RMSE (NRMSE): 0.2776

# %%
import matplotlib.pyplot as plt


# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(y_actual_tttt.flatten(), label='Actual PM 2.5')
plt.plot(y_pred_tttt.flatten(), label='Predicted PM 2.5')

# Add labels and title
plt.xlabel('Observation')
plt.ylabel('PM 2.5 Values')
plt.title('Comparison of Actual and Predicted PM 2.5 Values')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
data = {'y_actual': y_actual_tttt.flatten(), 'y_pred': y_pred_tttt.flatten()}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('unseen_predict_28.csv', index=False)
