# %%
# Import libraries

# %%
import xarray as xr
import glob
import pandas as pd
import numpy as np

# %%
df = xr.open_dataset(r"D:\PM_DATA\UNZIPED_DATA\albedo\gfs.0p25.2015011500.f006.grib2.nc")
df
# Out:
# <xarray.Dataset>
# Dimensions:                (time: 1, ntb: 2, lat: 13, lon: 21)
# Coordinates:
#   * time                   (time) datetime64[ns] 2015-01-15T06:00:00
#   * lat                    (lat) float32 24.0 23.75 23.5 ... 21.5 21.25 21.0
#   * lon                    (lon) float32 85.0 85.25 85.5 ... 89.5 89.75 90.0
# Dimensions without coordinates: ntb
# Data variables:
#     time_bnds              (time, ntb) datetime64[ns] ...
#     valid_date_time_range  (time, ntb) |S10 ...
#     ref_date_time          (time) |S10 ...
#     forecast_hour          (time) timedelta64[ns] ...
#     ALBDO_L1_Avg_1         (time, lat, lon) float32 ...
# Attributes:
#     Creation date and time:  2023-09-12 05:13:29 -0600
#     Conventions:             CF-1.5
#     Creator:                 NCAR - CISL RDA (dattore)

# %% [markdown]
# ## Read all nc file and combine all into a single file

# %%
# # List all the .nc files in the directory
# nc_files = glob.glob(r'D:\PM_DATA\UNZIPED_DATA\albedo\*.nc')

# # Open all the .nc files using xarray
# datasets = [xr.open_dataset(file) for file in nc_files]

# # Combine the datasets along a new dimension (e.g., 'time')
# combined_dataset = xr.concat(datasets, dim='time')

# # Save the combined dataset to a new .nc file
# combined_dataset.to_netcdf(r'D:\PM_DATA\EXTRACTED_NETCDF_DATA\Albedo.nc')

# # Close the datasets
# for ds in datasets:
#     ds.close()

# %%
df = xr.open_dataset(r"D:\PM_DATA\EXTRACTED_NETCDF_DATA\Albedo.nc")

# %%
df
# Out:
# <xarray.Dataset>
# Dimensions:                (time: 12636, ntb: 2, lat: 13, lon: 21)
# Coordinates:
#   * time                   (time) datetime64[ns] 2015-01-15T06:00:00 ... 2023...
#   * lat                    (lat) float32 24.0 23.75 23.5 ... 21.5 21.25 21.0
#   * lon                    (lon) float32 85.0 85.25 85.5 ... 89.5 89.75 90.0
# Dimensions without coordinates: ntb
# Data variables:
#     time_bnds              (time, ntb) datetime64[ns] ...
#     valid_date_time_range  (time, ntb) |S10 ...
#     ref_date_time          (time) |S10 ...
#     forecast_hour          (time) timedelta64[ns] ...
#     ALBDO_L1_Avg_1         (time, lat, lon) float32 ...
# Attributes:
#     Creation date and time:  2023-09-12 05:13:29 -0600
#     Conventions:             CF-1.5
#     Creator:                 NCAR - CISL RDA (dattore)

# %%
df = df['ALBDO_L1_Avg_1'].to_dataframe()

# %%
df
# Out:
#                                 ALBDO_L1_Avg_1
# time                lat  lon
# 2015-01-15 06:00:00 24.0 85.00       17.299999
#                          85.25       18.000000
#                          85.50       19.700001
#                          85.75       20.000000
#                          86.00       20.500000
# ...                                        ...
# 2023-09-10 18:00:00 21.0 89.00        8.150000
#                          89.25        7.580000
#                          89.50        6.660000
#                          89.75        6.710000
#                          90.00        6.060000
#
# [3449628 rows x 1 columns]

# %%
df = df.reset_index()

# %%
df
# Out:
#                        time   lat    lon  ALBDO_L1_Avg_1
# 0       2015-01-15 06:00:00  24.0  85.00       17.299999
# 1       2015-01-15 06:00:00  24.0  85.25       18.000000
# 2       2015-01-15 06:00:00  24.0  85.50       19.700001
# 3       2015-01-15 06:00:00  24.0  85.75       20.000000
# 4       2015-01-15 06:00:00  24.0  86.00       20.500000
# ...                     ...   ...    ...             ...
# 3449623 2023-09-10 18:00:00  21.0  89.00        8.150000
# 3449624 2023-09-10 18:00:00  21.0  89.25        7.580000
# 3449625 2023-09-10 18:00:00  21.0  89.50        6.660000
# 3449626 2023-09-10 18:00:00  21.0  89.75        6.710000
# 3449627 2023-09-10 18:00:00  21.0  90.00        6.060000
#
# [3449628 rows x 4 columns]

# %%
df.to_csv("D:\PM_DATA\CSV_DATA\Albedo.csv")
